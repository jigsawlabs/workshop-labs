# %% [markdown]
# # Overfitting in Decision Trees

# %% [markdown]
# ### Introduction

# %% [markdown]
# In previous lessons we have seen that we can use a decision tree to choose the features that will split our data according to the range of target variables.  For example, if we look at the decision tree for customer leads, we can see that our tree perfectly segmented our dataset between customers and non-customers.

# %% [markdown]
# ![](DTreeViz_customers.svg)

# %% [markdown]
# ### Working with a larger dataset

# %%
from sklearn.datasets import load_diabetes
from sklearn.model_selection import train_test_split
dataset = load_diabetes()
X = dataset['data']
y = dataset['target']

# %%
# print(dataset['DESCR'])

# %%
X_train.shape
# Out:
# (296, 10)

# %% [markdown]
# ### Working with Regression Trees

# %%
import pandas as pd
df = pd.DataFrame(X_train, columns = dataset['feature_names'])

# %%
df.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.009016 -0.044642 -0.030996  0.021872  0.008063  0.008707  0.004460
# 1 -0.001882 -0.044642  0.054152 -0.066495  0.072732  0.056619 -0.043401
# 2  0.009016  0.050680 -0.005128 -0.064199  0.069981  0.083863 -0.039719
# 3  0.038076  0.050680 -0.009439  0.002363  0.001183  0.037517 -0.054446
# 4  0.027178  0.050680  0.025051  0.014987  0.025950  0.048477 -0.039719
#
#          s4        s5        s6
# 0 -0.002592  0.009436  0.011349
# 1  0.084863  0.084495  0.048628
# 2  0.071210  0.039540  0.019633
# 3  0.050176 -0.025952  0.106617
# 4  0.034309  0.007837  0.023775

# %%
# y

# %% [markdown]
# ### Overfitting in Regression Trees

# %%
X_train, X_test, y_train, y_test = train_test_split(
     X, y, test_size=0.33, random_state=42)

# %%
# score on training

# %%
# score on testing

# %% [markdown]
# Hmmm...bummer.

# %% [markdown]
# Here is just a small portion of the decision tree that was created above.

# %% [markdown]
# ![](./d-tree.png)

# %%
# DecisionTreeRegressor(min_samples_leaf=1, max_depth=1)

# %% [markdown]
# ### Choosing the correct level of specificity

# %% [markdown]
# Let's work with our `min_samples_leaf` feature.  We can start with a minimum sample of two observations.  How do we know the correct number to use for max depth.  Well max depth is a hyperparameter, and so we can try various hyperparameters and score the performance against the test set.

# %%
from graph import trace_values, plot

# %% [markdown]
# 2. Now fit decision tree again with correct number

# %% [markdown]
# 3. Let's view the tree.

# %%
from dtreeviz.trees import *
viz = dtreeviz(dtc,
               X_train,
               y_train,
               target_name='disease progression',
               feature_names=dataset['feature_names'],
              )
              
viz
